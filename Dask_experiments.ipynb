# %%
from dask.distributed import Client

# Start Dask client with 4 workers, each having 4GB memory
client = Client(n_workers=2, threads_per_worker=1, memory_limit='8GB')
client  # This will print the dashboard link (e.g., http://localhost:8787/status)
# Out:
# <Client: 'tcp://127.0.0.1:54346' processes=2 threads=2, memory=14.90 GiB>

# %%
import dask.dataframe as dd

# Step 1: Load the dataset
data = dd.read_parquet('TRAIN_Reco_2021_2022_2023.parquet.gzip', blocksize='50MB')

# Step 2: Shuffle the data by 'ID' and create 672 partitions, one for each unique ID
data = data.shuffle(on="ID", npartitions=672)

# %%
data.npartitions
# Out:
# 672

# %%
partition_0 = data.partitions[0].compute()
partition_0
# Out:
# 2024-10-20 16:55:03,590 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3f0098d3e0d934ba1d2bc8e7e644e460 initialized by task ('shuffle-transfer-3f0098d3e0d934ba1d2bc8e7e644e460', 6) executed on worker tcp://127.0.0.1:54357
# 2024-10-20 16:55:17,380 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3f0098d3e0d934ba1d2bc8e7e644e460 deactivated due to stimulus 'task-finished-1729436117.379161'
# 2024-10-20 16:56:07,198 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3b6ace5f3966d2f48224ffe1f1feeefd initialized by task ('shuffle-transfer-3b6ace5f3966d2f48224ffe1f1feeefd', 6) executed on worker tcp://127.0.0.1:54357
# 2024-10-20 16:57:07,531 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3b6ace5f3966d2f48224ffe1f1feeefd deactivated due to stimulus 'task-finished-1729436227.529538'
# Empty DataFrame
# Columns: [ID, high, low, close, volume]
# Index: []

# %%
# Check the size (number of rows) of each partition
partition_sizes = data.map_partitions(len).compute()
print(partition_sizes)
# Out:
# 0           0
# 1           0
# 2      103877
# 3           0
# 4      103877
#         ...
# 667         0
# 668    103877
# 669    207754
# 670    207754
# 671         0
# Length: 672, dtype: int64

# %%
# Updated feature engineering function for Dask
import pandas as pd


def create_lagged_features(df):
    # Generate lagged features (for the past 10 time steps)
    for lag in range(1, 11):
        df[f'High_lag_{lag}'] = df['high'].shift(lag)
        df[f'Low_lag_{lag}'] = df['low'].shift(lag)
        df[f'Close_lag_{lag}'] = df['close'].shift(lag)
        df[f'Volume_lag_{lag}'] = df['volume'].shift(lag)
    
    return df

def create_rolling_features(df):
    # Rolling window features (mean for a 10-step window)
    df['High_rolling_mean_10'] = df['high'].rolling(window=10).mean()
    df['Low_rolling_mean_10'] = df['low'].rolling(window=10).mean()
    df['Close_rolling_mean_10'] = df['close'].rolling(window=10).mean()
    
    return df

# Assuming `ddf` is your Dask DataFrame
# Apply the lagged features in parallel using `map_partitions`
lagged_df = data.map_partitions(create_lagged_features)

meta = pd.DataFrame({
    'ID': pd.Series(dtype='object'),  # Include 'ID' as an object (or its correct dtype)
    'high': pd.Series(dtype='float64'),
    'low': pd.Series(dtype='float64'),
    'close': pd.Series(dtype='float64'),
    'volume': pd.Series(dtype='float64'),
    # Add the lagged columns in the correct order
    'High_lag_1': pd.Series(dtype='float64'),
    'Low_lag_1': pd.Series(dtype='float64'),
    'Close_lag_1': pd.Series(dtype='float64'),
    'Volume_lag_1': pd.Series(dtype='float64'),
    'High_lag_2': pd.Series(dtype='float64'),
    'Low_lag_2': pd.Series(dtype='float64'),
    'Close_lag_2': pd.Series(dtype='float64'),
    'Volume_lag_2': pd.Series(dtype='float64'),
    'High_lag_3': pd.Series(dtype='float64'),
    'Low_lag_3': pd.Series(dtype='float64'),
    'Close_lag_3': pd.Series(dtype='float64'),
    'Volume_lag_3': pd.Series(dtype='float64'),
    'High_lag_4': pd.Series(dtype='float64'),
    'Low_lag_4': pd.Series(dtype='float64'),
    'Close_lag_4': pd.Series(dtype='float64'),
    'Volume_lag_4': pd.Series(dtype='float64'),
    'High_lag_5': pd.Series(dtype='float64'),
    'Low_lag_5': pd.Series(dtype='float64'),
    'Close_lag_5': pd.Series(dtype='float64'),
    'Volume_lag_5': pd.Series(dtype='float64'),
    'High_lag_6': pd.Series(dtype='float64'),
    'Low_lag_6': pd.Series(dtype='float64'),
    'Close_lag_6': pd.Series(dtype='float64'),
    'Volume_lag_6': pd.Series(dtype='float64'),
    'High_lag_7': pd.Series(dtype='float64'),
    'Low_lag_7': pd.Series(dtype='float64'),
    'Close_lag_7': pd.Series(dtype='float64'),
    'Volume_lag_7': pd.Series(dtype='float64'),
    'High_lag_8': pd.Series(dtype='float64'),
    'Low_lag_8': pd.Series(dtype='float64'),
    'Close_lag_8': pd.Series(dtype='float64'),
    'Volume_lag_8': pd.Series(dtype='float64'),
    'High_lag_9': pd.Series(dtype='float64'),
    'Low_lag_9': pd.Series(dtype='float64'),
    'Close_lag_9': pd.Series(dtype='float64'),
    'Volume_lag_9': pd.Series(dtype='float64'),
    'High_lag_10': pd.Series(dtype='float64'),
    'Low_lag_10': pd.Series(dtype='float64'),
    'Close_lag_10': pd.Series(dtype='float64'),
    'Volume_lag_10': pd.Series(dtype='float64'),
    # Add the rolling mean columns
    'High_rolling_mean_10': pd.Series(dtype='float64'),
    'Low_rolling_mean_10': pd.Series(dtype='float64'),
    'Close_rolling_mean_10': pd.Series(dtype='float64')
})
# Apply the rolling window operation with `map_overlap`
# `map_overlap` is used for operations that need to "look back" across partitions
rolled_df = lagged_df.map_overlap(create_rolling_features, 
                                  before=10,  # Window size for overlap
                                  after=0,  # No overlap after the window
                                  meta=meta)  # Metadata to ensure Dask knows the structure

# Drop NaN values caused by shifting and rolling
clean_df = rolled_df.dropna()

# Trigger the computation (if needed)
# final_df = clean_df.compute()  # You can trigger the computation or write to file

# %%
clean_df
# Out:
# Dask DataFrame Structure:
#                      ID     high      low    close   volume High_lag_1 Low_lag_1 Close_lag_1 Volume_lag_1 High_lag_2 Low_lag_2 Close_lag_2 Volume_lag_2 High_lag_3 Low_lag_3 Close_lag_3 Volume_lag_3 High_lag_4 Low_lag_4 Close_lag_4 Volume_lag_4 High_lag_5 Low_lag_5 Close_lag_5 Volume_lag_5 High_lag_6 Low_lag_6 Close_lag_6 Volume_lag_6 High_lag_7 Low_lag_7 Close_lag_7 Volume_lag_7 High_lag_8 Low_lag_8 Close_lag_8 Volume_lag_8 High_lag_9 Low_lag_9 Close_lag_9 Volume_lag_9 High_lag_10 Low_lag_10 Close_lag_10 Volume_lag_10 High_rolling_mean_10 Low_rolling_mean_10 Close_rolling_mean_10
# npartitions=100
#                  object  float64  float64  float64  float64    float64   float64     float64      float64    float64   float64     float64      float64    float64   float64     float64      float64    float64   float64     float64      float64    float64   float64     float64      float64    float64   float64     float64      float64    float64   float64     float64      float64    float64   float64     float64      float64    float64   float64     float64      float64     float64    float64      float64       float64              float64             float64               float64
#                     ...      ...      ...      ...      ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...         ...        ...          ...           ...                  ...                 ...                   ...
# ...                 ...      ...      ...      ...      ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...         ...        ...          ...           ...                  ...                 ...                   ...
#                     ...      ...      ...      ...      ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...         ...        ...          ...           ...                  ...                 ...                   ...
#                     ...      ...      ...      ...      ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...        ...       ...         ...          ...         ...        ...          ...           ...                  ...                 ...                   ...
# Dask Name: dropna, 5 expressions
# Expr=DropnaFrame(frame=MapPartitions(create_rolling_features))

# %%
# Convert Dask DataFrame to Pandas (this requires enough memory, so ensure it's manageable)
import pandas as pd
pandas_data = clean_df.compute()
# Out:
# 2024-10-20 16:38:51,503 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:51043 (pid=11312) exceeded 95% memory budget. Restarting...
# 2024-10-20 16:38:51,625 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:51043 (pid=11312) is slow to terminate; trying again
# 2024-10-20 16:38:51,680 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:51043' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 84), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 87), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 90), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 96), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 35), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 93), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 99), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 38), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 44), ('repartitiontomore-15c318879f0bc9608abaa4eaf04b89d2', 30), ('create_lagged_features-5c5990d133649125ab7da8fee6934e18', 3), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 41), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 47), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 53), ('create_lagged_features-5c5990d133649125ab7da8fee6934e18', 9), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 50), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 4), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 68), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 7), ('split-repartitiontomore-15c318879f0bc9608abaa4eaf04b89d2', 2), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 89), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 34), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 86), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 92), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 98), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 37), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 40), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 46), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 43), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 49), ('create_lagged_features-5c5990d133649125ab7da8fee6934e18', 14), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 52), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 55), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 6), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 9), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 79), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 76), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 85), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 91), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 88), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 33), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 39), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 97), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 36), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 42), ('repartitiontomore-15c318879f0bc9608abaa4eaf04b89d2', 31), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 45), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 51), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 48), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 54), ('create_lagged_features-5c5990d133649125ab7da8fee6934e18', 13), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 8), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 60), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 5), ('split-repartitiontomore-15c318879f0bc9608abaa4eaf04b89d2', 0), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 75), ('_overlap_chunk-dropna-b9143a568f3eeda787fbb76ead1dd00c', 14)} (stimulus_id='handle-worker-cleanup-1729435131.679129')
# 2024-10-20 16:38:53,011 - distributed.nanny - WARNING - Restarting worker
# 2024-10-20 16:40:06,664 - distributed.scheduler - ERROR - Task ('repartitiontofewer-9d01a8ee34636910b7f1420ab28438b4', 0) has 25.95 GiB worth of input dependencies, but worker tcp://127.0.0.1:51046 has memory_limit set to 7.45 GiB.
# 2024-10-20 16:53:19,486 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3f0098d3e0d934ba1d2bc8e7e644e460 initialized by task ('shuffle-transfer-3f0098d3e0d934ba1d2bc8e7e644e460', 6) executed on worker tcp://127.0.0.1:51046
# 2024-10-20 16:53:36,176 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3f0098d3e0d934ba1d2bc8e7e644e460 deactivated due to stimulus 'task-finished-1729436016.1752322'
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Convert Dask DataFrame to Pandas (this requires enough memory, so ensure it's manageable)
#       2 import pandas as pd
# ----> 3 pandas_data = clean_df.compute()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dask_expr\_collection.py:481, in FrameBase.compute(self, fuse, concatenate, **kwargs)
#     479     out = out.repartition(npartitions=1)
#     480 out = out.optimize(fuse=fuse)
# --> 481 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dask\base.py:372, in DaskMethodsMixin.compute(self, **kwargs)
#     348 def compute(self, **kwargs):
#     349     """Compute this dask collection
#     350
#     351     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     370     dask.compute
#     371     """
# --> 372     (result,) = compute(self, traverse=False, **kwargs)
#     373     return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dask\base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\distributed\client.py:2417, in Client._gather(self, futures, errors, direct, local_worker)
#    2415     exception = st.exception
#    2416     traceback = st.traceback
# -> 2417     raise exception.with_traceback(traceback)
#    2418 if errors == "skip":
#    2419     bad_keys.add(key)
#
# MemoryError: Task ('repartitiontofewer-9d01a8ee34636910b7f1420ab28438b4', 0) has 25.95 GiB worth of input dependencies, but worker tcp://127.0.0.1:51046 has memory_limit set to 7.45 GiB.

# %%
# Ensure your date column is properly formatted as datetime
pandas_data['date'] = pd.to_datetime(pandas_data['date'])
pandas_data.set_index('date', inplace=True)

# %%
# Apply rolling mean operation using map_overlap
df['rolling_mean'] = df['feature'].map_overlap(lambda x: x.rolling(10).mean(), window=10, meta=('feature', 'f8'))
